# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
import time
from urllib.error import HTTPError

def crawl_page(url):
    try:
        # Send a request to the URL
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        response = urlopen(req)

        # Read the HTML content of the page
        html_content = response.read()

        # Create a BeautifulSoup object to parse the HTML
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract the information you need from the page
        # For example, print all the links on the page
        for link in soup.find_all('a'):
            print(link.get('href'))

    except HTTPError as e:
        print(f"Error accessing the URL: {url}")
        print(f"Error message: {e}")

    # Pause for a few seconds before crawling the next page
    time.sleep(2)

# %%
url = "https://example.com"
crawl_page(url)
# Out:
# https://www.iana.org/domains/example

# %%
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")
 
# to search
query = "site:jobs.lever.co Data Science Intern OR Internship remote"
query += " -BANGALORE"
query += " -talentkompass"
query += " -BERLIN"
query += " -fullstacklabs"
query += " -tokenmetrics"
query += " -MALAYSIA"
query += " -SINGAPORE"
query += " -VIETNAM"
query += " -POZNAN"
query += " -FRANCE"
query += " -veeva"
query += " -bluelightconsulting"
query += " -ExploreJobsSearch"
query += " -equiphealth"
query += " -equiphealth"
query += " -ONTARIO"
query += " -PARIS"
query += " -MUMBAI"
query += " -GURUGRAM"
query += " -CALGARY"
query += " -SYDNEY"
query += " -OTTAWA"
query += " -MAKITI"
query += " -LONDON"
query += " -SPAIN"
query += " -DHAKA"
query += " -StubHubHoldings"
query += " -AMSTERDAM"
query += " -ISTANBUL"
query += " -MILAN"
query += " -ITALY"
query += " -CANADA"

for j in search(query, tld="co.in", num=200, stop=200, pause=2):
    url = j
    dashes = url.count('/')
    if dashes > 3:
        print(url)
# Out:
# https://jobs.lever.co/videahealth/dda0c9a4-a134-40cd-9159-6c6216293f76
# https://jobs.lever.co/gametime/739192d2-7080-489b-8a4c-ef6de25fc276
# https://jobs.lever.co/overbond/3982e23c-e913-4a51-b237-7108cf3a3fc1
# https://jobs.lever.co/dott/af25cb9d-a1ec-4a91-a336-2f36726b9fef
# https://jobs.lever.co/economicmodeling/7255bc59-460c-4bd2-a752-7e4ec6bc02bb
# https://jobs.lever.co/LumaAi/9aebf86e-ef5f-4d24-8309-9c6cd0e80e97
# https://jobs.lever.co/pathrise/41e2d369-0f35-4091-80e3-6a1b84545f24
# https://jobs.lever.co/climateai/13ae5814-ed34-48be-b0a0-ac0d5f418ae2
# https://jobs.lever.co/chainlink/c79ebded-4d90-417f-8958-fbaffdae6018
# https://jobs.lever.co/overbond/3982e23c-e913-4a51-b237-7108cf3a3fc1/apply
# https://jobs.lever.co/openx/c9539338-9afe-4638-aaeb-e1e04e1ca6a0
# https://jobs.lever.co/certik/095fdcff-99e8-408d-bb8a-e638e44d0b40
# https://jobs.lever.co/certik/2e33570a-f495-44ef-9d7d-a0c5a7fd8190
# https://jobs.lever.co/opengov/6685f3d3-9d1e-4e6c-a2e9-d80bf762eee1
# ...
